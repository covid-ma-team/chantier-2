# %%
import requests

import json
import pandas as pd


# //////////////////////////////
# using xlsx file form Tafra
# //////////////////////////////

tafra_file = 'tafra.xlsx'
df = pd.read_excel(tafra_file)
communes = df['commune'].unique()
print(len(communes))
# Out:
# 1529

# %%
files_with_ids = {'id':[], 'path_file': []}

for c in communes:
    id_file = c
    
    commune = c.replace(' ', '+')
    region = ''
    country = 'Morocco'
    query = commune + '+' + region + '+' + country
    file_name = commune + '_' + region + '_' + country + '.geojson'
    folder = './geojson2/'

    files_with_ids['id'].append(id_file)
    files_with_ids['path_file'] = folder + file_name}

    polygon_geojson = '1'
    format_file = 'geojson'
    # url = 'https://nominatim.openstreetmap.org/search.php?q=' + \
    #    query + '&polygon_geojson=1&format=geojson'

    url = 'https://nominatim.openstreetmap.org/search.php?q=' + \
        query + '&' + \
        'polygon_geojson=' + polygon_geojson + '&' + \
        'format=' + format_file

    '''
    url = 'https://nominatim.openstreetmap.org/search.php?q=' + \
        'city=' + commune + ',' + \
        'country=' + country + '&' + \
        'polygon_geojson=' + polygon_geojson + '&' + \
        'format=' + format_file
    '''

    #r = requests.get(url, allow_redirects=True)
    #open(folder + file_name, 'wb').write(r.content)

    print(query)
# Out:
#   File "<ipython-input-3-83b1b4e7295e>", line 1
#     files_with_ids = {'id':][], 'path_file': []}
#                            ^
# SyntaxError: invalid syntax
